# %% [markdown]
# ### Run accuracy validation for given prompts on different models

# %%
from pathlib import Path
import sys
import json
import os

IN_GITHUB = os.getenv("GITHUB_ACTIONS") == "true"
try:
    import google.colab

    IN_COLAB = True
    print("Running as a Colab notebook")
except:
  IN_COLAB = False
  print("Not running as a Colab notebook")

if IN_COLAB:
  # !pip install transformer_lens
  # !pip install Levenshtein
  # !pip install anthropic
  from google.colab import drive
  drive.mount('/content/drive')
  ! pwd # Returns /content
  ! cp "/content/drive/MyDrive/Colab Notebooks/.env.example" /content/.env.example
  from dotenv import load_dotenv
  load_dotenv(".env.example")
# Out:
# Running as a Colab notebook
# Requirement already satisfied: transformer_lens in /usr/local/lib/python3.12/dist-packages (2.17.0)
# Requirement already satisfied: accelerate>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (1.13.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.0.3)
# Requirement already satisfied: datasets>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.0.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.8.2)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.36.2)
# Requirement already satisfied: jaxtyping>=0.2.11 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.3.9)
# Requirement already satisfied: numpy<2,>=1.26 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (2.2.2)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (5.29.6)
# Requirement already satisfied: rich>=12.6.0 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (13.9.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.2.1)
# Requirement already satisfied: torch>=2.6 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (2.10.0+cu128)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.67.3)
# Requirement already satisfied: transformers>=4.51 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.57.6)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.5.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (4.15.0)
# Requirement already satisfied: wandb>=0.13.5 in /usr/local/lib/python3.12/dist-packages (from transformer_lens) (0.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.23.0->transformer_lens) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (3.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer_lens) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformer_lens) (1.4.2)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping>=0.2.11->transformer_lens) (0.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer_lens) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer_lens) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer_lens) (2025.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.6.0->transformer_lens) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.6.0->transformer_lens) (2.19.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.6->transformer_lens) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.6->transformer_lens) (1.4.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51->transformer_lens) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51->transformer_lens) (0.22.2)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (4.9.4)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer_lens) (2.54.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (3.13.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer_lens) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer_lens) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->transformer_lens) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.6->transformer_lens) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.6->transformer_lens) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.23.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer_lens) (5.0.3)
# Requirement already satisfied: Levenshtein in /usr/local/lib/python3.12/dist-packages (0.27.3)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from Levenshtein) (3.14.3)
# Requirement already satisfied: anthropic in /usr/local/lib/python3.12/dist-packages (0.86.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content

# %% [markdown]
# 1. Read the dataset, prepare inputs

# %%
prompts = [
    "When John and Mary went to the shops, John gave the bag to",
    "When John and Mary went to the shops, Mary gave the bag to",
    "When Tom and James went to the park, James gave the ball to",
    "When Tom and James went to the park, Tom gave the ball to",
    "When Dan and Sid went to the shops, Sid gave an apple to",
    "When Dan and Sid went to the shops, Dan gave an apple to",
    "After Martin and Amy went to the park, Amy gave a drink to",
    "After Martin and Amy went to the park, Martin gave a drink to",
]
answers = [
    (" Mary", " John"),
    (" John", " Mary"),
    (" Tom", " James"),
    (" James", " Tom"),
    (" Dan", " Sid"),
    (" Sid", " Dan"),
    (" Martin", " Amy"),
    (" Amy", " Martin"),
]

correct_answers = []
incorrect_answers = []

for idx, prompt in enumerate(prompts):
    correct_answers.append(answers[idx][0])
    incorrect_answers.append(answers[idx][1])

# %%
models = ["Qwen/Qwen2.5-1.5B", "Qwen/Qwen2.5-3B", "Qwen/Qwen2.5-7B", "Qwen/Qwen3-0.6B", "Qwen/Qwen3-1.7B", "Qwen/Qwen3-4B", "Qwen/Qwen3-8B"]

# %%
# Expected results of validation:
# - Full model accuracy: can model accurately recognize that question implies different Indirect Objects?
# - Label prediction: can model correctly predict that next token after a prompt will be ' Mary' or ' John' names? (Also checks the model's conformance to a format)
# - Separtability of IO/Subject term: how good does the model separate raw logits corresponding to the ' Mary' and ' John' indirect object and subject in statements? What about probabilities of these logits?
# - If dataset contains contrastive pairs, is there one circuit differentiating them or two? Are they really "contrastive" for LLMs?

# %%
import anthropic
import json

# Additional AI-powered validation of the model's answer:
validation_prompt = """You are validating the correctness of LLM's completion to the following statement.
Statement: \"{statement}\"
You need to study the generated text of the model to understand which name LLM model has chosen as name of Indirect Object.
Please be aware that input prompt (or statement) is prepended to the generated text of the model, so the model's output will contain it.
Model's output: \"{model_output}\"
After identification of model's completion of the statement in the sense of indirect object, please compare its completion to the expected indirect object \"{expected_io}\".
Do completions match?
"""
validation_response_format = {
  "format": {
      "type": "json_schema",
      "schema": {
          "type": "object",
          "properties": {
          "is_correct": {
              "type": "boolean",
              "description": "True if model completed statement correctly, False if not"
              }
          },
          "required": ["is_correct"],
          "additionalProperties": False
      }
  }
}

def ask_claude_for_correctness(statement, model_output, expected_io):
    try:
        client = anthropic.Anthropic()

        response = client.messages.create(
            model="claude-opus-4-6",
            max_tokens=1024,
            messages=[
                {
                    "role": "user",
                    "content": validation_prompt.format(statement=statement, model_output=model_output, expected_io=expected_io),
                }
            ],
            output_config=validation_response_format
        )
        json_object = json.loads(response.content[0].text)
        return json_object["is_correct"]
    except Exception as e:
        return f"Error quering the Claude-Opus-4.6: {str(e)}"

# Commented debug line:
ask_claude_for_correctness("When John and Mary went to the shops, John gave the bag to",
                           "When John and Mary went to the shops, John gave the bag to Mary",
                          " Mary")
# Out:
# True

# %%
from transformer_lens import (
    HookedTransformer
)
import torch
import Levenshtein
import anthropic
import json
import numpy as np
import gc


first_tokens_accuracy_for_models = {}
classification_accuracy_for_models = {}
logits_diff_for_models = {}
probs_diff_for_models = {}


for model_name in models:
  gc.collect()
  # Create a model
  model = HookedTransformer.from_pretrained(model_name)

  # Tokenize prompts
  all_prompts_tokens = []
  for prompt in prompts:
    tokens = model.to_tokens(prompt)
    all_prompts_tokens.append(tokens)
  # Some verbose for visual validation of results
  for i in range(len(prompts)):
    string_tokens = [f"{i}, {model.to_string(t)}" for i, t in enumerate(all_prompts_tokens[i][0])]
    print(string_tokens)

  # Correct classifications to IO vs Subject:
  correct_classifications = 0
  # Correct classifications of expected next token predictions:
  # It measures complex phenomena: correct guessing of sentence completion and model's conformance to the asked format.
  correct_first_tokens = 0

  correct_answer_logits = []
  correct_answer_probs = []
  incorrect_answer_logits = []
  incorrect_answer_probs = []

  # Also variables for extra verbosing
  top3_tokens = []
  top3_logits = []
  for index, prompt_tokens in enumerate(all_prompts_tokens):
    logits, cache = model.run_with_cache(prompt_tokens)
    del cache
    gc.collect()

    # Only for verbosing purpose:
    sorted_logits = torch.sort(logits[-1, -1, :], descending=True)
    top3_tokens.append(sorted_logits.indices[0:3].cpu().detach())
    top3_logits.append(sorted_logits.values[0:3].cpu().detach().numpy())

    # Measuring IO <-> Subject separability.
    # IO <-> Subject distance calculation in raw logits and probabilities of
    # logits after applying the softmax
    correct_answer = correct_answers[index]
    incorrect_answer = incorrect_answers[index]

    correct_token = model.to_single_token(correct_answers[index])
    incorrect_token = model.to_single_token(incorrect_answers[index])

    correct_answer_logits.append(logits[-1, -1, correct_token].cpu().detach().numpy())
    incorrect_answer_logits.append(logits[-1, -1, incorrect_token].cpu().detach().numpy())

    log_probs = torch.nn.functional.softmax(logits[-1, -1, :], dim=-1)
    correct_answer_probs.append(log_probs[correct_token].cpu().detach().numpy())
    incorrect_answer_probs.append(log_probs[incorrect_token].cpu().detach().numpy())

    # Accuracy of labels prediction: accuracy of next-token prediction to be exactly the label we want.
    # Accuracy of complex phenomena: correct guessing of sentence completion and model's conformance to the asked format.
    first_token = model.to_string(top3_tokens[index][0])
    correctness_ratio = Levenshtein.ratio(first_token, correct_answers[index])
    if correctness_ratio > 0.9:
      correct_first_tokens += 1
    print(f"\n\nFor prompt: {prompts[index]}:\n")
    print(f"First token: {first_token}, correct answer: {correct_answer}, similarity: {correctness_ratio}")

    # Accuracy of classification to IO/Subject based on model's output context
    resulted_text = model.generate(prompt_tokens, max_new_tokens=20, do_sample=False, return_type='str', verbose=False)
    print(f"Resulted text: {resulted_text}")
    is_classification_correct = ask_claude_for_correctness(prompts[index], resulted_text, correct_answer)
    print(f"Classification is correct: {is_classification_correct}")
    correct_classifications += int(is_classification_correct)


    del logits
    del sorted_logits
    gc.collect()
  print(f"For model {model_name}: top-3 tokens = {model.to_string(torch.stack(top3_tokens))}")
  print(f"For model {model_name}: top-3 logits = {top3_logits}")
  print(f"For model {model_name}: correct first tokens = {correct_first_tokens}")
  print(f"For model {model_name}: correct classifications = {correct_classifications}")
  print(f"For model {model_name}: First token accuracy = {float(correct_first_tokens)/len(all_prompts_tokens)}")
  print(f"For model {model_name}: Classification accuracy = {float(correct_classifications)/len(all_prompts_tokens)}")
  print(f"For model {model_name}: correct answer logits = {correct_answer_logits}")
  print(f"For model {model_name}: incorrect answer logits = {incorrect_answer_logits}")
  print(f"For model {model_name}: correct answer probs = {correct_answer_probs}")
  print(f"For model {model_name}: incorrect answer probs = {incorrect_answer_probs}")

  first_tokens_accuracy_for_models[model_name] = float(correct_first_tokens)/len(all_prompts_tokens)
  classification_accuracy_for_models[model_name] = float(correct_classifications)/len(all_prompts_tokens)
  logits_diff_for_models[model_name] = np.abs(np.array(correct_answer_logits) - np.array(incorrect_answer_logits)).mean()
  probs_diff_for_models[model_name] = np.abs(np.array(correct_answer_probs) - np.array(incorrect_answer_probs)).mean()
  del top3_tokens

  print(f"First tokens accuracy for models: {first_tokens_accuracy_for_models}")
  print(f"Classification accuracy for models: {classification_accuracy_for_models}")
  print(f"Logits diff for models: {logits_diff_for_models}")
  print(f"Probs diff for models: {probs_diff_for_models}")
  del top3_logits
  del all_prompts_tokens
  del model

  gc.collect()
# Out:
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model Qwen/Qwen2.5-1.5B into HookedTransformer
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  John', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Mary', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  James', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Tom', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Sid', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Dan', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Amy', '10,  gave', '11,  a', '12,  drink', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Martin', '10,  gave', '11,  a', '12,  drink', '13,  to']
#
#
# For prompt: When John and Mary went to the shops, John gave the bag to:
#
# First token:  Mary, correct answer:  Mary, similarity: 1.0
# Resulted text: When John and Mary went to the shops, John gave the bag to Mary.  Given the context: What will John want to do next?  Possible answers: be
# Classification is correct: True
#
#
# For prompt: When John and Mary went to the shops, Mary gave the bag to:
#
# First token:  John, correct answer:  John, similarity: 1.0
# Resulted text: When John and Mary went to the shops, Mary gave the bag to John.  Given the context: What will John want to do next?  Possible answers: take
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, James gave the ball to:
#
# First token:  Tom, correct answer:  Tom, similarity: 1.0
# Resulted text: When Tom and James went to the park, James gave the ball to Tom.  Given the context: What will happen to Tom?  Possible answers: be happy,
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, Tom gave the ball to:
#
# First token:  James, correct answer:  James, similarity: 1.0
# Resulted text: When Tom and James went to the park, Tom gave the ball to James.  Given the context: What will happen to Tom?  Possible answers: be happy,
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Sid gave an apple to:
#
# First token:  every, correct answer:  Dan, similarity: 0.19999999999999996
# Resulted text: When Dan and Sid went to the shops, Sid gave an apple to every person who had bought an ice cream. If Sid had 10 apples and there were
# Classification is correct: False
#
#
# For prompt: When Dan and Sid went to the shops, Dan gave an apple to:
#
# First token:  every, correct answer:  Sid, similarity: 0.19999999999999996
# Resulted text: When Dan and Sid went to the shops, Dan gave an apple to every person in the first 3 waiting queues. Sid, on the other hand, gave a banana
# Classification is correct: False
#
#
# For prompt: After Martin and Amy went to the park, Amy gave a drink to:
#
# First token:  Martin, correct answer:  Martin, similarity: 1.0
# Resulted text: After Martin and Amy went to the park, Amy gave a drink to Martin.  Given the context: What will happen to Amy?  Possible answers: be thanked,
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Martin gave a drink to:
#
# First token:  each, correct answer:  Amy, similarity: 0.2222222222222222
# Resulted text: After Martin and Amy went to the park, Martin gave a drink to each of the 10 children. If each drink costs $1.50, how much
# Classification is correct: False
# For model Qwen/Qwen2.5-1.5B: top-3 tokens = [' Mary his a', ' John her a', ' Tom his a', ' James his Mike', ' every each the', ' every each Sid', ' Martin a each', ' each a the']
# For model Qwen/Qwen2.5-1.5B: top-3 logits = [array([22.875309, 20.26763 , 19.328735], dtype=float32), array([23.398525, 20.319532, 19.098274], dtype=float32), array([22.199892, 19.276024, 18.278692], dtype=float32), array([21.082205, 20.12892 , 19.367085], dtype=float32), array([22.553236, 22.358564, 21.15626 ], dtype=float32), array([23.157867, 22.938723, 22.24358 ], dtype=float32), array([19.565815, 18.782204, 18.687662], dtype=float32), array([19.843653, 19.574678, 19.15071 ], dtype=float32)]
# For model Qwen/Qwen2.5-1.5B: correct first tokens = 5
# For model Qwen/Qwen2.5-1.5B: correct classifications = 5
# For model Qwen/Qwen2.5-1.5B: First token accuracy = 0.625
# For model Qwen/Qwen2.5-1.5B: Classification accuracy = 0.625
# For model Qwen/Qwen2.5-1.5B: correct answer logits = [array(22.875309, dtype=float32), array(23.398525, dtype=float32), array(22.199892, dtype=float32), array(21.082205, dtype=float32), array(21.015312, dtype=float32), array(22.24358, dtype=float32), array(19.565815, dtype=float32), array(19.050476, dtype=float32)]
# For model Qwen/Qwen2.5-1.5B: incorrect answer logits = [array(15.14525, dtype=float32), array(13.103009, dtype=float32), array(13.746181, dtype=float32), array(16.493301, dtype=float32), array(8.688969, dtype=float32), array(13.006667, dtype=float32), array(10.067762, dtype=float32), array(12.175131, dtype=float32)]
# For model Qwen/Qwen2.5-1.5B: correct answer probs = [array(0.87022567, dtype=float32), array(0.9076475, dtype=float32), array(0.79149413, dtype=float32), array(0.20936146, dtype=float32), array(0.07890718, dtype=float32), array(0.14625132, dtype=float32), array(0.31651536, dtype=float32), array(0.10991007, dtype=float32)]
# For model Qwen/Qwen2.5-1.5B: incorrect answer probs = [array(0.00038239, dtype=float32), array(3.0664185e-05, dtype=float32), array(0.00016867, dtype=float32), array(0.00212795, dtype=float32), array(3.4982716e-07, dtype=float32), array(1.4241626e-05, dtype=float32), array(2.3737935e-05, dtype=float32), array(0.00011353, dtype=float32)]
# First tokens accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625}
# Classification accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625}
# Logits diff for models: {'Qwen/Qwen2.5-1.5B': 8.625605}
# Probs diff for models: {'Qwen/Qwen2.5-1.5B': 0.4284314}
# config.json:   0%|          | 0.00/683 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model Qwen/Qwen2.5-3B into HookedTransformer
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  John', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Mary', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  James', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Tom', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Sid', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Dan', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Amy', '10,  gave', '11,  a', '12,  drink', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Martin', '10,  gave', '11,  a', '12,  drink', '13,  to']
#
#
# For prompt: When John and Mary went to the shops, John gave the bag to:
#
# First token:  Mary, correct answer:  Mary, similarity: 1.0
# Resulted text: When John and Mary went to the shops, John gave the bag to Mary.  Given the context: What will Mary want to do next?  Possible answers: give
# Classification is correct: True
#
#
# For prompt: When John and Mary went to the shops, Mary gave the bag to:
#
# First token:  John, correct answer:  John, similarity: 1.0
# Resulted text: When John and Mary went to the shops, Mary gave the bag to John. John was carrying a bag with 100 apples. He gave Mary 20
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, James gave the ball to:
#
# First token:  Tom, correct answer:  Tom, similarity: 1.0
# Resulted text: When Tom and James went to the park, James gave the ball to Tom.  Given the context: What will happen to James?  Possible answers: be happy,
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, Tom gave the ball to:
#
# First token:  James, correct answer:  James, similarity: 1.0
# Resulted text: When Tom and James went to the park, Tom gave the ball to James.  Given the context: What will James want to do next?  Possible answers: throw
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Sid gave an apple to:
#
# First token:  Dan, correct answer:  Dan, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Sid gave an apple to Dan. Dan ate half of the apple and gave the rest to Sid. Sid ate half of the
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Dan gave an apple to:
#
# First token:  Sid, correct answer:  Sid, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Dan gave an apple to Sid. Sid ate the apple and gave a quarter of the apples he had to Dan. Dan ate
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Amy gave a drink to:
#
# First token:  each, correct answer:  Martin, similarity: 0.33333333333333337
# Resulted text: After Martin and Amy went to the park, Amy gave a drink to each of them. If each bottle of drink contains 10 servings and each serving has 1
# Classification is correct: False
#
#
# For prompt: After Martin and Amy went to the park, Martin gave a drink to:
#
# First token:  each, correct answer:  Amy, similarity: 0.2222222222222222
# Resulted text: After Martin and Amy went to the park, Martin gave a drink to each of them. If each bottle of drink contains 10 servings and costs $0.5
# Classification is correct: False
# For model Qwen/Qwen2.5-3B: top-3 tokens = [' Mary his the', ' John her the', ' Tom his the', ' James his the', ' Dan every each', ' Sid each his', ' each one ', ' each  Amy']
# For model Qwen/Qwen2.5-3B: top-3 logits = [array([22.650751, 19.389446, 18.783129], dtype=float32), array([21.743694, 19.07779 , 18.479353], dtype=float32), array([22.167463, 18.431206, 18.371014], dtype=float32), array([22.897003, 18.920454, 18.144424], dtype=float32), array([21.741873, 21.260807, 21.242916], dtype=float32), array([23.783886, 20.094883, 20.057562], dtype=float32), array([20.513197, 20.04781 , 19.836746], dtype=float32), array([20.592375, 20.297483, 20.0182  ], dtype=float32)]
# For model Qwen/Qwen2.5-3B: correct first tokens = 6
# For model Qwen/Qwen2.5-3B: correct classifications = 6
# For model Qwen/Qwen2.5-3B: First token accuracy = 0.75
# For model Qwen/Qwen2.5-3B: Classification accuracy = 0.75
# For model Qwen/Qwen2.5-3B: correct answer logits = [array(22.650751, dtype=float32), array(21.743694, dtype=float32), array(22.167463, dtype=float32), array(22.897003, dtype=float32), array(21.741873, dtype=float32), array(23.783886, dtype=float32), array(19.561357, dtype=float32), array(20.0182, dtype=float32)]
# For model Qwen/Qwen2.5-3B: incorrect answer logits = [array(16.872322, dtype=float32), array(16.220814, dtype=float32), array(14.780044, dtype=float32), array(15.331, dtype=float32), array(15.02143, dtype=float32), array(12.180639, dtype=float32), array(14.590549, dtype=float32), array(11.867515, dtype=float32)]
# For model Qwen/Qwen2.5-3B: correct answer probs = [array(0.90049917, dtype=float32), array(0.80430746, dtype=float32), array(0.88761884, dtype=float32), array(0.9402156, dtype=float32), array(0.35791877, dtype=float32), array(0.90474886, dtype=float32), array(0.07868072, dtype=float32), array(0.13131917, dtype=float32)]
# For model Qwen/Qwen2.5-3B: incorrect answer probs = [array(0.00278576, dtype=float32), array(0.00321267, dtype=float32), array(0.00054943, dtype=float32), array(0.0004868, dtype=float32), array(0.00043165, dtype=float32), array(8.266126e-06, dtype=float32), array(0.00054585, dtype=float32), array(3.789051e-05, dtype=float32)]
# First tokens accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75}
# Classification accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75}
# Logits diff for models: {'Qwen/Qwen2.5-1.5B': 8.625605, 'Qwen/Qwen2.5-3B': 7.212489}
# Probs diff for models: {'Qwen/Qwen2.5-1.5B': 0.4284314, 'Qwen/Qwen2.5-3B': 0.62465626}
# config.json:   0%|          | 0.00/686 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model Qwen/Qwen2.5-7B into HookedTransformer
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  John', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Mary', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  James', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Tom', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Sid', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Dan', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Amy', '10,  gave', '11,  a', '12,  drink', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Martin', '10,  gave', '11,  a', '12,  drink', '13,  to']
#
#
# For prompt: When John and Mary went to the shops, John gave the bag to:
#
# First token:  Mary, correct answer:  Mary, similarity: 1.0
# Resulted text: When John and Mary went to the shops, John gave the bag to Mary.  Given the context: What will Mary want to do next?  Possible answers: put
# Classification is correct: True
#
#
# For prompt: When John and Mary went to the shops, Mary gave the bag to:
#
# First token:  John, correct answer:  John, similarity: 1.0
# Resulted text: When John and Mary went to the shops, Mary gave the bag to John to carry.  Given the context: What will happen to John?  Possible answers: be
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, James gave the ball to:
#
# First token:  Tom, correct answer:  Tom, similarity: 1.0
# Resulted text: When Tom and James went to the park, James gave the ball to Tom.  Given the context: What will James want to do next?  Possible answers: throw
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, Tom gave the ball to:
#
# First token:  James, correct answer:  James, similarity: 1.0
# Resulted text: When Tom and James went to the park, Tom gave the ball to James. What is the relationship between Tom and James?
# The relationship between Tom and James is that Tom
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Sid gave an apple to:
#
# First token:  each, correct answer:  Dan, similarity: 0.4444444444444444
# Resulted text: When Dan and Sid went to the shops, Sid gave an apple to each of the 100 people he met. Dan, on the other hand, gave a
# Classification is correct: False
#
#
# For prompt: When Dan and Sid went to the shops, Dan gave an apple to:
#
# First token:  each, correct answer:  Sid, similarity: 0.2222222222222222
# Resulted text: When Dan and Sid went to the shops, Dan gave an apple to each of the 100 people he met. Sid gave each person 2 apples. How
# Classification is correct: False
#
#
# For prompt: After Martin and Amy went to the park, Amy gave a drink to:
#
# First token:  Martin, correct answer:  Martin, similarity: 1.0
# Resulted text: After Martin and Amy went to the park, Amy gave a drink to Martin. What did Amy give to Martin?  Answer choices: - a drink  - a hug
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Martin gave a drink to:
#
# First token:  a, correct answer:  Amy, similarity: 0.33333333333333337
# Resulted text: After Martin and Amy went to the park, Martin gave a drink to a homeless person. Amy was shocked and asked Martin why he did that. Martin explained that he wanted
# Classification is correct: False
# For model Qwen/Qwen2.5-7B: top-3 tokens = [' Mary his a', ' John her a', ' Tom his their', ' James his the', ' each a Dan', ' each every a', ' Martin each a', ' a each Amy']
# For model Qwen/Qwen2.5-7B: top-3 logits = [array([20.104836, 17.213163, 16.583147], dtype=float32), array([19.263458, 16.900862, 16.477652], dtype=float32), array([17.754333, 16.243925, 15.671434], dtype=float32), array([17.44867 , 16.577824, 16.270609], dtype=float32), array([18.796412, 18.116228, 17.977896], dtype=float32), array([18.947504, 18.213554, 17.842152], dtype=float32), array([17.919352, 17.804537, 17.657715], dtype=float32), array([17.96818 , 17.857847, 17.68745 ], dtype=float32)]
# For model Qwen/Qwen2.5-7B: correct first tokens = 5
# For model Qwen/Qwen2.5-7B: correct classifications = 5
# For model Qwen/Qwen2.5-7B: First token accuracy = 0.625
# For model Qwen/Qwen2.5-7B: Classification accuracy = 0.625
# For model Qwen/Qwen2.5-7B: correct answer logits = [array(20.104836, dtype=float32), array(19.263458, dtype=float32), array(17.754333, dtype=float32), array(17.44867, dtype=float32), array(17.977896, dtype=float32), array(16.294016, dtype=float32), array(17.919352, dtype=float32), array(17.68745, dtype=float32)]
# For model Qwen/Qwen2.5-7B: incorrect answer logits = [array(15.624634, dtype=float32), array(13.732022, dtype=float32), array(12.96254, dtype=float32), array(15.753015, dtype=float32), array(10.768903, dtype=float32), array(13.023555, dtype=float32), array(12.594288, dtype=float32), array(11.764436, dtype=float32)]
# For model Qwen/Qwen2.5-7B: correct answer probs = [array(0.7359802, dtype=float32), array(0.62368006, dtype=float32), array(0.32039055, dtype=float32), array(0.17427914, dtype=float32), array(0.1429308, dtype=float32), array(0.0261101, dtype=float32), array(0.19663389, dtype=float32), array(0.13848175, dtype=float32)]
# For model Qwen/Qwen2.5-7B: incorrect answer probs = [array(0.00833949, dtype=float32), array(0.00246996, dtype=float32), array(0.00265846, dtype=float32), array(0.03197657, dtype=float32), array(0.00010575, dtype=float32), array(0.00099189, dtype=float32), array(0.00095722, dtype=float32), array(0.00037073, dtype=float32)]
# First tokens accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625}
# Classification accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625}
# Logits diff for models: {'Qwen/Qwen2.5-1.5B': 8.625605, 'Qwen/Qwen2.5-3B': 7.212489, 'Qwen/Qwen2.5-7B': 4.778327}
# Probs diff for models: {'Qwen/Qwen2.5-1.5B': 0.4284314, 'Qwen/Qwen2.5-3B': 0.62465626, 'Qwen/Qwen2.5-7B': 0.28882706}
# WARNING:root:Loading model Qwen/Qwen3-0.6B requires setting trust_remote_code=True
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# WARNING:root:Loading model Qwen/Qwen3-0.6B state dict requires setting trust_remote_code=True
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model Qwen/Qwen3-0.6B into HookedTransformer
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  John', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Mary', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  James', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Tom', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Sid', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Dan', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Amy', '10,  gave', '11,  a', '12,  drink', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Martin', '10,  gave', '11,  a', '12,  drink', '13,  to']
#
#
# For prompt: When John and Mary went to the shops, John gave the bag to:
#
# First token:  Mary, correct answer:  Mary, similarity: 1.0
# Resulted text: When John and Mary went to the shops, John gave the bag to Mary, and Mary gave the bag to John. Then, they went to the store and bought a
# Classification is correct: True
#
#
# For prompt: When John and Mary went to the shops, Mary gave the bag to:
#
# First token:  John, correct answer:  John, similarity: 1.0
# Resulted text: When John and Mary went to the shops, Mary gave the bag to John, and John gave the bag to Mary. So, the bag was passed from Mary to John
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, James gave the ball to:
#
# First token:  Tom, correct answer:  Tom, similarity: 1.0
# Resulted text: When Tom and James went to the park, James gave the ball to Tom. Tom and James were both happy. What is the probability that the ball is still in the
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, Tom gave the ball to:
#
# First token:  James, correct answer:  James, similarity: 1.0
# Resulted text: When Tom and James went to the park, Tom gave the ball to James. James then gave the ball back to Tom. The ball was initially at James's house.
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Sid gave an apple to:
#
# First token:  Dan, correct answer:  Dan, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Sid gave an apple to Dan. Then, Dan gave an apple to Sid. After that, they both had 10
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Dan gave an apple to:
#
# First token:  Sid, correct answer:  Sid, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Dan gave an apple to Sid, and Sid gave him a new apple. How many apples did they have at the end of
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Amy gave a drink to:
#
# First token:  Martin, correct answer:  Martin, similarity: 1.0
# Resulted text: After Martin and Amy went to the park, Amy gave a drink to Martin. Martin and Amy went to the park for a total of 3 hours. How many hours
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Martin gave a drink to:
#
# First token:  his, correct answer:  Amy, similarity: 0.25
# Resulted text: After Martin and Amy went to the park, Martin gave a drink to his dog. The dog was a dog. The dog was a dog. The dog was a dog
# Classification is correct: False
# For model Qwen/Qwen3-0.6B: top-3 tokens = [' Mary his the', ' John the a', ' Tom his the', ' James his the', ' Dan the his', ' Sid his a', ' Martin the each', ' his Amy each']
# For model Qwen/Qwen3-0.6B: top-3 logits = [array([20.037554, 17.932472, 17.615143], dtype=float32), array([18.972118, 17.095371, 15.971435], dtype=float32), array([20.08413 , 18.396185, 17.432096], dtype=float32), array([21.109888, 18.206139, 17.84622 ], dtype=float32), array([20.191273, 16.71746 , 15.971606], dtype=float32), array([19.151968, 16.993929, 16.621347], dtype=float32), array([18.914774, 17.411385, 17.40969 ], dtype=float32), array([18.226715, 17.90151 , 17.543816], dtype=float32)]
# For model Qwen/Qwen3-0.6B: correct first tokens = 7
# For model Qwen/Qwen3-0.6B: correct classifications = 7
# For model Qwen/Qwen3-0.6B: First token accuracy = 0.875
# For model Qwen/Qwen3-0.6B: Classification accuracy = 0.875
# For model Qwen/Qwen3-0.6B: correct answer logits = [array(20.037554, dtype=float32), array(18.972118, dtype=float32), array(20.08413, dtype=float32), array(21.109888, dtype=float32), array(20.191273, dtype=float32), array(19.151968, dtype=float32), array(18.914774, dtype=float32), array(17.90151, dtype=float32)]
# For model Qwen/Qwen3-0.6B: incorrect answer logits = [array(14.498004, dtype=float32), array(15.484351, dtype=float32), array(14.897328, dtype=float32), array(14.625538, dtype=float32), array(10.515845, dtype=float32), array(12.198234, dtype=float32), array(13.029994, dtype=float32), array(12.35586, dtype=float32)]
# For model Qwen/Qwen3-0.6B: correct answer probs = [array(0.74552697, dtype=float32), array(0.6249969, dtype=float32), array(0.68110037, dtype=float32), array(0.8506346, dtype=float32), array(0.8378325, dtype=float32), array(0.64003235, dtype=float32), array(0.47515216, dtype=float32), array(0.20833392, dtype=float32)]
# For model Qwen/Qwen3-0.6B: incorrect answer probs = [array(0.00292865, dtype=float32), array(0.01910556, dtype=float32), array(0.00380726, dtype=float32), array(0.00129905, dtype=float32), array(5.2622625e-05, dtype=float32), array(0.00061127, dtype=float32), array(0.00132162, dtype=float32), array(0.00081342, dtype=float32)]
# First tokens accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625, 'Qwen/Qwen3-0.6B': 0.875}
# Classification accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625, 'Qwen/Qwen3-0.6B': 0.875}
# Logits diff for models: {'Qwen/Qwen2.5-1.5B': 8.625605, 'Qwen/Qwen2.5-3B': 7.212489, 'Qwen/Qwen2.5-7B': 4.778327, 'Qwen/Qwen3-0.6B': 6.0947576}
# Probs diff for models: {'Qwen/Qwen2.5-1.5B': 0.4284314, 'Qwen/Qwen2.5-3B': 0.62465626, 'Qwen/Qwen2.5-7B': 0.28882706, 'Qwen/Qwen3-0.6B': 0.6292088}
# WARNING:root:Loading model Qwen/Qwen3-1.7B requires setting trust_remote_code=True
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# WARNING:root:Loading model Qwen/Qwen3-1.7B state dict requires setting trust_remote_code=True
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/622M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model Qwen/Qwen3-1.7B into HookedTransformer
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  John', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Mary', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  James', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Tom', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Sid', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Dan', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Amy', '10,  gave', '11,  a', '12,  drink', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Martin', '10,  gave', '11,  a', '12,  drink', '13,  to']
#
#
# For prompt: When John and Mary went to the shops, John gave the bag to:
#
# First token:  Mary, correct answer:  Mary, similarity: 1.0
# Resulted text: When John and Mary went to the shops, John gave the bag to Mary, and Mary gave the bag to John. Then, they both had the same number of mar
# Classification is correct: True
#
#
# For prompt: When John and Mary went to the shops, Mary gave the bag to:
#
# First token:  John, correct answer:  John, similarity: 1.0
# Resulted text: When John and Mary went to the shops, Mary gave the bag to John.  John gave the bag to Mary.  Then, they both had the bag.
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, James gave the ball to:
#
# First token:  Tom, correct answer:  Tom, similarity: 1.0
# Resulted text: When Tom and James went to the park, James gave the ball to Tom.  The ball was red.  The ball was round.  Tom and James were playing
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, Tom gave the ball to:
#
# First token:  James, correct answer:  James, similarity: 1.0
# Resulted text: When Tom and James went to the park, Tom gave the ball to James.  The ball was red.  The ball was round.  The ball was soft.
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Sid gave an apple to:
#
# First token:  Dan, correct answer:  Dan, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Sid gave an apple to Dan. Dan then gave a chocolate to Sid. After that, Dan went to the shops again,
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Dan gave an apple to:
#
# First token:  Sid, correct answer:  Sid, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Dan gave an apple to Sid, and then they each bought a bag of apples. How many apples did they have in total
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Amy gave a drink to:
#
# First token:  Martin, correct answer:  Martin, similarity: 1.0
# Resulted text: After Martin and Amy went to the park, Amy gave a drink to Martin.  The next day, Martin gave a drink to Amy.  Martin and Amy each had
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Martin gave a drink to:
#
# First token:  a, correct answer:  Amy, similarity: 0.33333333333333337
# Resulted text: After Martin and Amy went to the park, Martin gave a drink to a child, and then Amy gave a drink to a child. After that, they went to a
# Classification is correct: False
# For model Qwen/Qwen3-1.7B: top-3 tokens = [' Mary his the', ' John the her', ' Tom his the', ' James his the', ' DanDan the', ' Sid a his', ' Martin a each', ' a each Amy']
# For model Qwen/Qwen3-1.7B: top-3 logits = [array([22.21776 , 18.79524 , 18.501055], dtype=float32), array([22.345325, 18.176605, 17.913797], dtype=float32), array([21.821264, 18.814526, 17.584587], dtype=float32), array([22.559546, 18.403389, 17.45697 ], dtype=float32), array([23.418644, 17.852276, 17.29868 ], dtype=float32), array([21.64779 , 19.6404  , 18.990673], dtype=float32), array([37.88487, 33.10192, 32.5626 ], dtype=float32), array([37.618927, 36.566624, 34.582973], dtype=float32)]
# For model Qwen/Qwen3-1.7B: correct first tokens = 7
# For model Qwen/Qwen3-1.7B: correct classifications = 7
# For model Qwen/Qwen3-1.7B: First token accuracy = 0.875
# For model Qwen/Qwen3-1.7B: Classification accuracy = 0.875
# For model Qwen/Qwen3-1.7B: correct answer logits = [array(22.21776, dtype=float32), array(22.345325, dtype=float32), array(21.821264, dtype=float32), array(22.559546, dtype=float32), array(23.418644, dtype=float32), array(21.64779, dtype=float32), array(37.88487, dtype=float32), array(34.582973, dtype=float32)]
# For model Qwen/Qwen3-1.7B: incorrect answer logits = [array(16.481195, dtype=float32), array(13.626112, dtype=float32), array(11.803231, dtype=float32), array(11.468912, dtype=float32), array(8.374642, dtype=float32), array(11.457701, dtype=float32), array(11.6759405, dtype=float32), array(14.031788, dtype=float32)]
# For model Qwen/Qwen3-1.7B: correct answer probs = [array(0.9203532, dtype=float32), array(0.95450306, dtype=float32), array(0.9117593, dtype=float32), array(0.96692854, dtype=float32), array(0.9883428, dtype=float32), array(0.777616, dtype=float32), array(0.98491645, dtype=float32), array(0.03382549, dtype=float32)]
# For model Qwen/Qwen3-1.7B: incorrect answer probs = [array(0.0029689, dtype=float32), array(0.00015598, dtype=float32), array(4.0654046e-05, dtype=float32), array(1.47500505e-05, dtype=float32), array(2.8932152e-07, dtype=float32), array(2.9192093e-05, dtype=float32), array(4.083259e-12, dtype=float32), array(4.0177008e-11, dtype=float32)]
# First tokens accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625, 'Qwen/Qwen3-0.6B': 0.875, 'Qwen/Qwen3-1.7B': 0.875}
# Classification accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625, 'Qwen/Qwen3-0.6B': 0.875, 'Qwen/Qwen3-1.7B': 0.875}
# Logits diff for models: {'Qwen/Qwen2.5-1.5B': 8.625605, 'Qwen/Qwen2.5-3B': 7.212489, 'Qwen/Qwen2.5-7B': 4.778327, 'Qwen/Qwen3-0.6B': 6.0947576, 'Qwen/Qwen3-1.7B': 13.444831}
# Probs diff for models: {'Qwen/Qwen2.5-1.5B': 0.4284314, 'Qwen/Qwen2.5-3B': 0.62465626, 'Qwen/Qwen2.5-7B': 0.28882706, 'Qwen/Qwen3-0.6B': 0.6292088, 'Qwen/Qwen3-1.7B': 0.8168794}
# WARNING:root:Loading model Qwen/Qwen3-4B requires setting trust_remote_code=True
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# WARNING:root:Loading model Qwen/Qwen3-4B state dict requires setting trust_remote_code=True
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model Qwen/Qwen3-4B into HookedTransformer
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  John', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Mary', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  James', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Tom', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Sid', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Dan', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Amy', '10,  gave', '11,  a', '12,  drink', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Martin', '10,  gave', '11,  a', '12,  drink', '13,  to']
#
#
# For prompt: When John and Mary went to the shops, John gave the bag to:
#
# First token:  Mary, correct answer:  Mary, similarity: 1.0
# Resulted text: When John and Mary went to the shops, John gave the bag to Mary. Then, when they came back, Mary gave the bag to John. What is the probability
# Classification is correct: True
#
#
# For prompt: When John and Mary went to the shops, Mary gave the bag to:
#
# First token:  Anna, correct answer:  John, similarity: 0.4
# Resulted text: When John and Mary went to the shops, Mary gave the bag to Anna.  John bought a new bag and gave it to Anna.  Then Anna gave the bag
# Classification is correct: False
#
#
# For prompt: When Tom and James went to the park, James gave the ball to:
#
# First token:  Tom, correct answer:  Tom, similarity: 1.0
# Resulted text: When Tom and James went to the park, James gave the ball to Tom 10 times. If they went to the park 15 times, how many times
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, Tom gave the ball to:
#
# First token:  James, correct answer:  James, similarity: 1.0
# Resulted text: When Tom and James went to the park, Tom gave the ball to James. Then James threw the ball into the air.  Then James caught it, and then Tom
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Sid gave an apple to:
#
# First token:  each, correct answer:  Dan, similarity: 0.4444444444444444
# Resulted text: When Dan and Sid went to the shops, Sid gave an apple to each of the children and one to each of the adults. He bought 120 apples.
# Classification is correct: False
#
#
# For prompt: When Dan and Sid went to the shops, Dan gave an apple to:
#
# First token:  Sid, correct answer:  Sid, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Dan gave an apple to Sid. Then Sid gave Dan a bottle of water. Then they both had 2 of each item
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Amy gave a drink to:
#
# First token:  a, correct answer:  Martin, similarity: 0.4444444444444444
# Resulted text: After Martin and Amy went to the park, Amy gave a drink to a man who was sitting on a bench. The man was very thirsty and asked for a drink.
# Classification is correct: False
#
#
# For prompt: After Martin and Amy went to the park, Martin gave a drink to:
#
# First token:  a, correct answer:  Amy, similarity: 0.33333333333333337
# Resulted text: After Martin and Amy went to the park, Martin gave a drink to a person who was waiting in line. Amy was waiting in line for the roller coaster. Who was
# Classification is correct: True
# For model Qwen/Qwen3-4B: top-3 tokens = [' Mary the his', ' Anna the John', ' Tom his the', ' James his james', ' each Dan Charlotte', ' Sid the a', ' a the each', ' a the Amy']
# For model Qwen/Qwen3-4B: top-3 logits = [array([26.494013, 23.073467, 22.34027 ], dtype=float32), array([24.811825, 24.353603, 24.1     ], dtype=float32), array([34.777473, 28.309826, 25.173128], dtype=float32), array([33.27082 , 27.0547  , 24.233913], dtype=float32), array([26.30906 , 24.858395, 23.532372], dtype=float32), array([28.320595, 23.729881, 23.676167], dtype=float32), array([20.148745, 19.563717, 17.72613 ], dtype=float32), array([20.052706, 19.327894, 19.297512], dtype=float32)]
# For model Qwen/Qwen3-4B: correct first tokens = 4
# For model Qwen/Qwen3-4B: correct classifications = 5
# For model Qwen/Qwen3-4B: First token accuracy = 0.5
# For model Qwen/Qwen3-4B: Classification accuracy = 0.625
# For model Qwen/Qwen3-4B: correct answer logits = [array(26.494013, dtype=float32), array(24.1, dtype=float32), array(34.777473, dtype=float32), array(33.27082, dtype=float32), array(24.858395, dtype=float32), array(28.320595, dtype=float32), array(16.640625, dtype=float32), array(19.297512, dtype=float32)]
# For model Qwen/Qwen3-4B: incorrect answer logits = [array(15.983226, dtype=float32), array(19.588257, dtype=float32), array(13.925908, dtype=float32), array(18.865229, dtype=float32), array(9.005739, dtype=float32), array(20.331797, dtype=float32), array(10.906782, dtype=float32), array(8.016735, dtype=float32)]
# For model Qwen/Qwen3-4B: correct answer probs = [array(0.9058241, dtype=float32), array(0.13727461, dtype=float32), array(0.9982748, dtype=float32), array(0.99751234, dtype=float32), array(0.16247566, dtype=float32), array(0.9729029, dtype=float32), array(0.01564612, dtype=float32), array(0.19896401, dtype=float32)]
# For model Qwen/Qwen3-4B: incorrect answer probs = [array(2.4675564e-05, dtype=float32), array(0.00150718, dtype=float32), array(8.780716e-10, dtype=float32), array(5.529033e-07, dtype=float32), array(2.1186908e-08, dtype=float32), array(0.00033005, dtype=float32), array(5.0609313e-05, dtype=float32), array(2.509547e-06, dtype=float32)]
# First tokens accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625, 'Qwen/Qwen3-0.6B': 0.875, 'Qwen/Qwen3-1.7B': 0.875, 'Qwen/Qwen3-4B': 0.5}
# Classification accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625, 'Qwen/Qwen3-0.6B': 0.875, 'Qwen/Qwen3-1.7B': 0.875, 'Qwen/Qwen3-4B': 0.625}
# Logits diff for models: {'Qwen/Qwen2.5-1.5B': 8.625605, 'Qwen/Qwen2.5-3B': 7.212489, 'Qwen/Qwen2.5-7B': 4.778327, 'Qwen/Qwen3-0.6B': 6.0947576, 'Qwen/Qwen3-1.7B': 13.444831, 'Qwen/Qwen3-4B': 11.39197}
# Probs diff for models: {'Qwen/Qwen2.5-1.5B': 0.4284314, 'Qwen/Qwen2.5-3B': 0.62465626, 'Qwen/Qwen2.5-7B': 0.28882706, 'Qwen/Qwen3-0.6B': 0.6292088, 'Qwen/Qwen3-1.7B': 0.8168794, 'Qwen/Qwen3-4B': 0.5483699}
# WARNING:root:Loading model Qwen/Qwen3-8B requires setting trust_remote_code=True
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# WARNING:root:Loading model Qwen/Qwen3-8B state dict requires setting trust_remote_code=True
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/3.19G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model Qwen/Qwen3-8B into HookedTransformer
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  John', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  John', '2,  and', '3,  Mary', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Mary', '10,  gave', '11,  the', '12,  bag', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  James', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Tom', '2,  and', '3,  James', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Tom', '10,  gave', '11,  the', '12,  ball', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Sid', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, When', '1,  Dan', '2,  and', '3,  Sid', '4,  went', '5,  to', '6,  the', '7,  shops', '8, ,', '9,  Dan', '10,  gave', '11,  an', '12,  apple', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Amy', '10,  gave', '11,  a', '12,  drink', '13,  to']
# ['0, After', '1,  Martin', '2,  and', '3,  Amy', '4,  went', '5,  to', '6,  the', '7,  park', '8, ,', '9,  Martin', '10,  gave', '11,  a', '12,  drink', '13,  to']
#
#
# For prompt: When John and Mary went to the shops, John gave the bag to:
#
# First token:  Mary, correct answer:  Mary, similarity: 1.0
# Resulted text: When John and Mary went to the shops, John gave the bag to Mary.  When they returned home, Mary gave the bag back to John.  When they went
# Classification is correct: True
#
#
# For prompt: When John and Mary went to the shops, Mary gave the bag to:
#
# First token:  John, correct answer:  John, similarity: 1.0
# Resulted text: When John and Mary went to the shops, Mary gave the bag to John. Then, when they went to the shops again, John gave the bag to Mary. What
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, James gave the ball to:
#
# First token:  Tom, correct answer:  Tom, similarity: 1.0
# Resulted text: When Tom and James went to the park, James gave the ball to Tom. Then, James kicked the ball, and it went into the bushes. Tom tried to retrieve
# Classification is correct: True
#
#
# For prompt: When Tom and James went to the park, Tom gave the ball to:
#
# First token:  James, correct answer:  James, similarity: 1.0
# Resulted text: When Tom and James went to the park, Tom gave the ball to James. James then gave the ball to his friend, and the friend gave it back to Tom.
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Sid gave an apple to:
#
# First token:  Dan, correct answer:  Dan, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Sid gave an apple to Dan. Then Dan gave Sid a banana. Then Sid gave Dan a pear. Then Dan gave Sid
# Classification is correct: True
#
#
# For prompt: When Dan and Sid went to the shops, Dan gave an apple to:
#
# First token:  Sid, correct answer:  Sid, similarity: 1.0
# Resulted text: When Dan and Sid went to the shops, Dan gave an apple to Sid. Then Sid gave Dan a banana. Then Dan gave Sid a pear. Then Sid gave Dan
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Amy gave a drink to:
#
# First token:  Martin, correct answer:  Martin, similarity: 1.0
# Resulted text: After Martin and Amy went to the park, Amy gave a drink to Martin.  Martin had a drink.  Amy had a drink.  Martin had a drink.
# Classification is correct: True
#
#
# For prompt: After Martin and Amy went to the park, Martin gave a drink to:
#
# First token:  Amy, correct answer:  Amy, similarity: 1.0
# Resulted text: After Martin and Amy went to the park, Martin gave a drink to Amy.  Amy gave a drink to Martin.  Martin gave a drink to Amy.  Amy
# Classification is correct: True
# For model Qwen/Qwen3-8B: top-3 tokens = [' Mary his the', ' John her the', ' Tom his the', ' James his the', ' Dan his the', ' Sid his each', ' Martin her a', ' Amy his the']
# For model Qwen/Qwen3-8B: top-3 logits = [array([24.085888, 18.569393, 18.341417], dtype=float32), array([23.30903 , 18.441086, 17.585596], dtype=float32), array([23.473957, 18.528587, 18.104973], dtype=float32), array([24.925524, 19.077908, 18.578901], dtype=float32), array([19.679409, 19.107895, 18.232468], dtype=float32), array([20.553226, 19.064957, 18.620638], dtype=float32), array([33.66274 , 27.097057, 25.34628 ], dtype=float32), array([31.878483, 27.568794, 26.911648], dtype=float32)]
# For model Qwen/Qwen3-8B: correct first tokens = 8
# For model Qwen/Qwen3-8B: correct classifications = 8
# For model Qwen/Qwen3-8B: First token accuracy = 1.0
# For model Qwen/Qwen3-8B: Classification accuracy = 1.0
# For model Qwen/Qwen3-8B: correct answer logits = [array(24.085888, dtype=float32), array(23.30903, dtype=float32), array(23.473957, dtype=float32), array(24.925524, dtype=float32), array(19.679409, dtype=float32), array(20.553226, dtype=float32), array(33.66274, dtype=float32), array(31.878483, dtype=float32)]
# For model Qwen/Qwen3-8B: incorrect answer logits = [array(16.80023, dtype=float32), array(16.007421, dtype=float32), array(15.109146, dtype=float32), array(14.610834, dtype=float32), array(8.0168915, dtype=float32), array(11.98728, dtype=float32), array(13.114141, dtype=float32), array(11.947111, dtype=float32)]
# For model Qwen/Qwen3-8B: correct answer probs = [array(0.98374224, dtype=float32), array(0.9713688, dtype=float32), array(0.9824436, dtype=float32), array(0.99362814, dtype=float32), array(0.44755012, dtype=float32), array(0.6592707, dtype=float32), array(0.9980142, dtype=float32), array(0.97312456, dtype=float32)]
# For model Qwen/Qwen3-8B: incorrect answer probs = [array(0.00067416, dtype=float32), array(0.00065514, dtype=float32), array(0.00022883, dtype=float32), array(3.2931468e-05, dtype=float32), array(3.853671e-06, dtype=float32), array(0.00012558, dtype=float32), array(1.1884866e-09, dtype=float32), array(2.1482442e-09, dtype=float32)]
# First tokens accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625, 'Qwen/Qwen3-0.6B': 0.875, 'Qwen/Qwen3-1.7B': 0.875, 'Qwen/Qwen3-4B': 0.5, 'Qwen/Qwen3-8B': 1.0}
# Classification accuracy for models: {'Qwen/Qwen2.5-1.5B': 0.625, 'Qwen/Qwen2.5-3B': 0.75, 'Qwen/Qwen2.5-7B': 0.625, 'Qwen/Qwen3-0.6B': 0.875, 'Qwen/Qwen3-1.7B': 0.875, 'Qwen/Qwen3-4B': 0.625, 'Qwen/Qwen3-8B': 1.0}
# Logits diff for models: {'Qwen/Qwen2.5-1.5B': 8.625605, 'Qwen/Qwen2.5-3B': 7.212489, 'Qwen/Qwen2.5-7B': 4.778327, 'Qwen/Qwen3-0.6B': 6.0947576, 'Qwen/Qwen3-1.7B': 13.444831, 'Qwen/Qwen3-4B': 11.39197, 'Qwen/Qwen3-8B': 11.746901}
# Probs diff for models: {'Qwen/Qwen2.5-1.5B': 0.4284314, 'Qwen/Qwen2.5-3B': 0.62465626, 'Qwen/Qwen2.5-7B': 0.28882706, 'Qwen/Qwen3-0.6B': 0.6292088, 'Qwen/Qwen3-1.7B': 0.8168794, 'Qwen/Qwen3-4B': 0.5483699, 'Qwen/Qwen3-8B': 0.87592775}

# %%
import pandas as pd

qwen2_ft_acc = {key : value for key, value in first_tokens_accuracy_for_models.items() if "Qwen2" in key}
qwen3_ft_acc = {key : value for key, value in first_tokens_accuracy_for_models.items() if "Qwen3" in key}
qwen2_ft_acc_df = pd.DataFrame(qwen2_ft_acc.values(), qwen2_ft_acc.keys(), columns=["Qwen2 first tokens accuracy"])
qwen3_ft_acc_df = pd.DataFrame(qwen3_ft_acc.values(), qwen3_ft_acc.keys(), columns=["Qwen3 first tokens accuracy"])
display(qwen2_ft_acc_df)
display(qwen3_ft_acc_df)

qwen2_acc = {key : value for key, value in classification_accuracy_for_models.items() if "Qwen2" in key}
qwen3_acc = {key : value for key, value in classification_accuracy_for_models.items() if "Qwen3" in key}
qwen2_acc_df = pd.DataFrame(qwen2_acc.values(), qwen2_acc.keys(), columns=["Qwen2 accuracy"])
qwen3_acc_df = pd.DataFrame(qwen3_acc.values(), qwen3_acc.keys(), columns=["Qwen3 accuracy"])
display(qwen2_acc_df)
display(qwen3_acc_df)

import matplotlib.pyplot as plt
ax = qwen2_ft_acc_df.plot(title="Qwen2 accuracy of recognizing Indirect Object")
qwen2_acc_df.plot(ax=ax)
for index in range(len(qwen2_acc.keys())):
    ax.text(index, qwen2_ft_acc_df.iloc[index, 0], round(qwen2_ft_acc_df.iloc[index, 0], 2), verticalalignment='top', ha='center', size=8, color='tab:blue', in_layout=True)
    ax.text(index, qwen2_acc_df.iloc[index, 0], round(qwen2_acc_df.iloc[index, 0], 2), verticalalignment='bottom', ha='center', size=8, color='tab:orange', in_layout=True)
plt.ylim(0, 1)

ax2 = qwen3_ft_acc_df.plot(title="Qwen3 accuracy of recognizing Indirect Object")
qwen3_acc_df.plot(ax=ax2)
for index in range(len(qwen3_acc.keys())):
    ax2.text(index, qwen3_ft_acc_df.iloc[index, 0], round(qwen3_ft_acc_df.iloc[index, 0], 3), verticalalignment='top', ha='center', size=8, color='tab:blue', in_layout=True)
    ax2.text(index, qwen3_acc_df.iloc[index, 0], round(qwen3_acc_df.iloc[index, 0], 3), verticalalignment='bottom', ha='center', size=8, color='tab:orange', in_layout=True)
plt.ylim(0, 1)
# Out:
#                    Qwen2 first tokens accuracy
# Qwen/Qwen2.5-1.5B                        0.625
# Qwen/Qwen2.5-3B                          0.750
# Qwen/Qwen2.5-7B                          0.625
#                  Qwen3 first tokens accuracy
# Qwen/Qwen3-0.6B                        0.875
# Qwen/Qwen3-1.7B                        0.875
# Qwen/Qwen3-4B                          0.500
# Qwen/Qwen3-8B                          1.000
#                    Qwen2 accuracy
# Qwen/Qwen2.5-1.5B           0.625
# Qwen/Qwen2.5-3B             0.750
# Qwen/Qwen2.5-7B             0.625
#                  Qwen3 accuracy
# Qwen/Qwen3-0.6B           0.875
# Qwen/Qwen3-1.7B           0.875
# Qwen/Qwen3-4B             0.625
# Qwen/Qwen3-8B             1.000
# (0.0, 1.0)

# %%
qwen2_log_diff = {key : value for key, value in logits_diff_for_models.items() if "Qwen2" in key}
qwen3_log_diff = {key : value for key, value in logits_diff_for_models.items() if "Qwen3" in key}
qwen2_log_diff_df = pd.DataFrame(qwen2_log_diff.values(), qwen2_log_diff.keys(), columns=["Qwen2 logit difference"])
qwen3_log_diff_df = pd.DataFrame(qwen3_log_diff.values(), qwen3_log_diff.keys(), columns=["Qwen3 logit difference"])
display(qwen2_log_diff_df)
display(qwen3_log_diff_df)

import matplotlib.pyplot as plt
ax = qwen2_log_diff_df.plot(title="Qwen2 logit differences between \" IO\" and \" Subject\" tokens in answers")
for index in range(len(qwen2_log_diff.keys())):
    ax.text(index, qwen2_log_diff_df.iloc[index, 0], round(qwen2_log_diff_df.iloc[index, 0], 2), verticalalignment='bottom', ha='center', size=8, color='tab:blue', in_layout=True)
plt.ylim(0, 15)

ax2 = qwen3_log_diff_df.plot(title="Qwen3 logit differences between \" IO\" and \" Subject\" tokens in answers", color='tab:orange')
for index in range(len(qwen3_log_diff.keys())):
    ax2.text(index, qwen3_log_diff_df.iloc[index, 0], round(qwen3_log_diff_df.iloc[index, 0], 2), verticalalignment='bottom', ha='center', size=8, color='tab:orange', in_layout=True)
plt.ylim(0, 15)
# Out:
#                    Qwen2 logit difference
# Qwen/Qwen2.5-1.5B                8.625605
# Qwen/Qwen2.5-3B                  7.212489
# Qwen/Qwen2.5-7B                  4.778327
#                  Qwen3 logit difference
# Qwen/Qwen3-0.6B                6.094758
# Qwen/Qwen3-1.7B               13.444831
# Qwen/Qwen3-4B                 11.391970
# Qwen/Qwen3-8B                 11.746901
# (0.0, 15.0)

# %%
qwen2_logits_probability_diff = {key : value for key, value in probs_diff_for_models.items() if "Qwen2" in key}
qwen3_logits_probability_diff = {key : value for key, value in probs_diff_for_models.items() if "Qwen3" in key}
qwen2_logits_probability_diff_df = pd.DataFrame(qwen2_logits_probability_diff.values(), qwen2_logits_probability_diff.keys(), columns=["Qwen2 logits probabilities difference"])
qwen3_logits_probability_diff_df = pd.DataFrame(qwen3_logits_probability_diff.values(), qwen3_logits_probability_diff.keys(), columns=["Qwen3 logits probabilities difference"])
display(qwen2_logits_probability_diff_df)
display(qwen3_logits_probability_diff_df)

import matplotlib.pyplot as plt
ax = qwen2_logits_probability_diff_df.plot(title="Qwen2 logits probabilities differences between \"IO\" and \"Subject\" tokens in answers")
for index in range(len(qwen2_logits_probability_diff.keys())):
    ax.text(index, qwen2_logits_probability_diff_df.iloc[index, 0], round(qwen2_logits_probability_diff_df.iloc[index, 0], 2), verticalalignment='bottom', ha='center', size=8, color='tab:blue', in_layout=True)
plt.ylim(0, 1)

ax2 = qwen3_logits_probability_diff_df.plot(title="Qwen3 logits probabilities differences between \"IO\" and \"Subject\" tokens in answers", color='tab:orange')
for index in range(len(qwen3_logits_probability_diff.keys())):
    ax2.text(index, qwen3_logits_probability_diff_df.iloc[index, 0], round(qwen3_logits_probability_diff_df.iloc[index, 0], 2), verticalalignment='bottom', ha='center', size=8, color='tab:orange', in_layout=True)
plt.ylim(0, 1)
# Out:
#                    Qwen2 logits probabilities difference
# Qwen/Qwen2.5-1.5B                               0.428431
# Qwen/Qwen2.5-3B                                 0.624656
# Qwen/Qwen2.5-7B                                 0.288827
#                  Qwen3 logits probabilities difference
# Qwen/Qwen3-0.6B                               0.629209
# Qwen/Qwen3-1.7B                               0.816879
# Qwen/Qwen3-4B                                 0.548370
# Qwen/Qwen3-8B                                 0.875928
# (0.0, 1.0)

# %% [markdown]
# Does the antagonisms of concepts increase with the model size?
